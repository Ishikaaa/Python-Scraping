# %%
import urllib.request
# requests modules helps to send all kind of HTTP request. 
import requests 
# BeautifulSoup in bs4 is used pasring HTML documents 
import bs4 
import time

# %%
print("Modules imported successfully")
# It helps to put cookies 
cj=http.cookiejar.CookieJar()
opener=urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
print("cookiejar")
urllib.request.install_opener(opener)
print("opener installed")
authentication_url="https://m.facebook.com/login.php"
emm=str(input("Enter your email id:"))
paa=str(input("Enter your password:"))
payload={
    'email':emm,
    'pass':paa
}
print("Check your entry:",payload)
data=urllib.parse.urlencode(payload).encode('utf-8')
req=urllib.request.Request(authentication_url,data)
print("request of login page")
resp=urllib.request.urlopen(req)
contents=resp.read()
print("Logged in succssfully")
print(contents)
# Out:
# Modules imported successfully
# cookiejar
# opener installed
# Enter your email id:gargishika1998@gmail.com
# Enter your password:6estfr!enD
# Check your entry: {'email': 'gargishika1998@gmail.com', 'pass': '6estfr!enD'}
# request of login page
# Logged in succssfully
# ...

# %%
# access 
aa=str(input('Enter name:'))
aa=aa.replace(" ", "+")
url="https://mbasic.facebook.com/search/top/?q="+aa
data=requests.get(url, cookies=cj)
soup=bs4.BeautifulSoup(data.text,'html.parser')
print(url)
print(soup.prettify())
# Out:
# Enter name:muskan goyal
# https://mbasic.facebook.com/search/top/?q=muskan+goyal+
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Results for "muskan goyal"
#   </title>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <style type="text/css">
# ...

# %%
# # for i in soup.find_all(class_="cc",href=True):
# #     print(i['a']['href'])
# #     print("\n\n")
# #     print("1")
# # #print(aaa)
# print("done")
# actual_person=[]
# p=0
# for i in soup.find_all('a',href=True):
#     i=i['href']
    
# print(actual_person) 
    
# #     if "add_friend.php" in i:
# #         print(i)
# #         actual_person.apppend(i)
# print("done")
# Out:
# done
# ['/muskan.goyal.7?refid=46', '/smile.garg.750?refid=46', '/graphsearch/str/muskan+goyal/keywords_users?f=AbrQAZfLmwMP6NlQKIRSad4cDpDTVyQKzXAi9NJXxU0hpAwf_S7YNpaKMG7DIMJeEWy8sgpIViOiKu5aYjM4_zprezle6VpZ8SDmPSxLUy2aR8E3jG9UUqn27QQDbEeZs5g&source=pivot&refid=46']
# done

# %%
# get friends profile link 
actual_person=[]
p=0
for i in soup.find_all('a',href=True):
    p+=1
    if p==13 or p==19:
        i=i['href']
        actual_person.append("https://mbasic.facebook.com"+i)
print(actual_person)
#print(actual_person)
# Out:
# ['https://mbasic.facebook.com/muskaan.goel.5?refid=46', 'https://mbasic.facebook.com/muskan.goyal.7?refid=46']

# %%
# accesing  profile page  
url_profile_page=actual_person[0]
data_profile_page=requests.get(url_profile_page, cookies=cj)
soup_profile_page=bs4.BeautifulSoup(data_profile_page.text,'html.parser')
print(soup_profile_page.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Muskaan Goel
#   </title>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <style type="text/css">
# ...

# %%
# access page of post 
z=[]
a_p_p=0
for i in soup_profile_page.find_all('a',href=True):
    #time.sleep(4)
    if i['href'][0:11]=="/story.php?" :
        a_p_p+=1
        if a_p_p==0 or a_p_p%3==0:
            z.append((i['href']))
print(z)
# Out:
# ['/story.php?story_fbid=2594072713972099&id=100001081885598&refid=17&_ft_=mf_story_key.2594072713972099%3Aog_action_id.2594072730638764%3Atop_level_post_id.2594072713972099%3Atl_objid.2594072713972099%3Acontent_owner_id_new.100001081885598%3Athrowback_story_fbid.2594072713972099%3Apage_id.1855597117800694%3Astory_location.4%3Astory_attachment_style.og_composer_simple%3Apage_insights.%7B%221855597117800694%22%3A%7B%22page_id%22%3A1855597117800694%2C%22role%22%3A4%2C%22actor_id%22%3A100001081885598%2C%22psn%22%3A%22EntStatusCreationStory%22%2C%22sl%22%3A4%2C%22dm%22%3A%7B%22isShare%22%3A0%2C%22originalPostOwnerID%22%3A0%7D%2C%22targets%22%3A%5B%7B%22page_id%22%3A1855597117800694%2C%22actor_id%22%3A100001081885598%2C%22role%22%3A4%7D%5D%7D%7D%3Athid.100001081885598%3A306061129499414%3A2%3A0%3A1561964399%3A-8053919215956202055&__tn__=%2AW-R#footer_action_list', '/story.php?story_fbid=2558675407511830&id=100001081885598&refid=17&_ft_=mf_story_key.2558675407511830%3Atop_level_post_id.25586
# ...

# %%
# access profile post page 
a_p_p_p=[]
for y in z:
    url_p_p_p="https://m.facebook.com/"+y
    data_p_p_p=requests.get(url_p_p_p,cookies=cj)
    soup_p_p_p=bs4.BeautifulSoup(data_p_p_p.text,'html.parser')
    for zzz in soup_p_p_p.title:
        if zzz.lower()=="comments":
            zzz="None"
        a_p_p_p.append(zzz)
print(a_p_p_p)
# Out:
# ['None', 'This world is absurdly beautiful 🌏 #niagarafalls', 'Wherever life plants you,bloom with grace 🙂 - such a great quote to always remember 🍁', 'None', 'None']
